# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
rdata = pd.read_csv('fall_guys_metacritic_reviews.csv')
rdata
# Out:
#          username review_type published_date  score  votes  \
# 0          Fen1ma        user   Aug 26, 2020    6.0    0.0
# 1        Locke_VI        user   Aug 25, 2020    3.0    0.0
# 2        Crisener        user   Aug 25, 2020    8.0    0.0
# 3    EnigmaXtreme        user   Aug 25, 2020    7.0    0.0
# 4        nitorita        user   Aug 23, 2020    7.0    0.0
# ..            ...         ...            ...    ...    ...
# 349      Sirvizel        user   Aug  5, 2020    1.0   12.0
# 350      Burst_H4        user   Aug  5, 2020    9.0    4.0
# 351    Jordanzone        user   Aug  5, 2020    8.0    6.0
# 352       Crissss        user   Aug  5, 2020    9.0    5.0
# 353          T68K        user   Aug  5, 2020    9.0    7.0
#
#                                            review_text  \
# 0    на данный момент не советую покупать игру, ещё...
# 1    Fall Guys was a game I was really looking forw...
# 2    You gotta love it. The aesthetics are very col...
# ...

# %%
# print(rdata['review_text'].to_string())
rdata['review_text'][3]
# Out:
# 'When we covered Fall Guys last week during it’s beta, we talked about how fun the game was with its crazy courses and bounce all over the place with your adorable jellybaby like characters. But expressed concern about its longevity from the variety of courses we played, however, we expected that what we were playing was just a mere taste and expected to see a bunch more in the fall game.\r<br/>\r<br/>Sad to say that hasn’t exactly been the case.\r<br/>\r<br/>For anyone not aware, Fall Guys is a brand new attempt at Battle Royale, where you play as bizarre little creatures who have a terrible centre of gravity and “wooo” everytime they get knocked over. The game plays a lot like Takeshi’s Castle and Wipeout with many similar obstacle courses like running through doors and avoiding the fake ones, only with more crowding and flailing all over the place. That is the one thing you need to expect while playing Fall Guys, it is going to become an absolute squabble especially when squeezing
# ...

# %%
word_freq = rdata.review_text.str.split(expand=True).stack().value_counts()
print(word_freq.to_string())
# Out:
# the                                                                                                                                                                              762
# and                                                                                                                                                                              623
# a                                                                                                                                                                                612
# to                                                                                                                                                                               494
# is                                                                                                                                                                               420
# ...
